# %% [markdown]
# ### 문제 1
# 20이하의 자연수 중 3으로 나눴을 때 나머지가 1인 숫자를 출력하기

# %%
# 정답을 써주세요

# %% [markdown]
# ### 문제2
# 다음과 같이 출력하기
# \*
# \*\*
# \*\*\*
# \*\*\*\*
# \*\*\*\*\*

# %%
# 정답을 써주세요

# %% [markdown]
# ####문제 3
# 고객의 개인정보보호를 위하여 이름을 비식별화 하여 출력하기
# 예시) 홍길동 → 홍\*동

# %%
names = ['홍길동', '홍계월', '김철수', '이영희', '박첨지']

# %%
# 정답을 써주세요
